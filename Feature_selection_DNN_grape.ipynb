# %% [markdown]
# ## Import packages

# %%
from keras.layers import Dense

import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import text
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from keras.models import Model
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers.core import Dense,Activation,Flatten,Dropout
from keras.layers.normalization import BatchNormalization
import numpy as np
from keras.layers import Input, Conv1D, MaxPooling1D, Concatenate
from keras.optimizers import adam, SGD, rmsprop
from keras import backend as K
from keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from keras.models import model_from_json
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import VarianceThreshold
from sklearn.ensemble import RandomForestClassifier
#from feature_selector import FeatureSelector
from sklearn.ensemble import RandomForestRegressor
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasRegressor

# %% [markdown]
# ## Read data

# %%
#%%df = pd.read_csv('test.csv')
xls = pd.ExcelFile('CA_MO_combined.xlsx')
df1 = pd.read_excel(xls, 'CA_MO_combined_raw')
df2 = pd.read_excel(xls, 'CA_MO_combined_1nm')

dataset = df1.values
# split into input (X) and output (Y) variables, and training/test data
X = dataset[:, 1:202]
Y = dataset[:, 209]   # Gs 205; Fs 209;

# %% [markdown]
# ## RFR-based feature selection

# %%
#%% Module-1: RFR-based Variable Importance selection
rf = RandomForestRegressor(n_estimators=1000) # Create a random forest regressor
rf.fit(X, Y) # Train the regressor
feature_importances = pd.DataFrame(rf.feature_importances_,index = X.columns,columns=['importance']).sort_values('importance',ascending=False) # show feature importance
accum_importance = np.cumsum(feature_importances)

idx = accum_importance[accum_importance['importance']<=0.99].index.tolist()[-1]
threshold = feature_importances.loc[idx]

sfm = SelectFromModel(rf, threshold=threshold) # Create a selector object that will use the random forest regressor to identify features that have an importance of more than the defined threshold
sfm.fit(X, Y) #Train the selector
X = sfm.transform(X) # Transform the data to create a new dataset containing only the most important features
X = pd.DataFrame(X) # Convert data format

# %% [markdown]
# ## PCA-based feature selection

# %%
#%% Module-2: PCA-based feature selection
pca = PCA(0.95)
pca.fit(X)
X = pca.transform(X)
print(pca.n_components_)

# %% [markdown]
# ## normalize and splite training/test data

# %%
#%% normalize data
scaler = MinMaxScaler(feature_range=(0, 1))
X = scaler.fit_transform(X)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state = 0)

num_features = X_train.shape[1]

print (X_train.shape,Y_train.shape,Y_test.shape,X_test.shape, num_features)
# Out:
# (170, 201) (170,) (73,) (73, 201) 201
# C:\Users\maimaitiyimingm\AppData\Local\conda\conda\envs\Tensorflow\lib\site-packages\sklearn\utils\validation.py:590: DataConversionWarning: Data with input dtype object was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# ## Build DNN layers

# %%
#%% Function to create model, required for KerasRegressor
def create_model(learn_rate,dropout_rate):
    model = Sequential()
    model.add(Dense(64, input_dim=num_features, kernel_initializer='normal', activation='relu'))
    model.add(Dense(128, input_dim=num_features, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dense(256, input_dim=num_features, activation='relu'))
    model.add(Dense(512, input_dim=num_features, activation='relu'))
    model.add(BatchNormalization())
#    model.add(Dense(512, input_dim=num_features, activation='relu'))
#    model.add(Dense(1024, input_dim=num_features, activation='relu'))
#    model.add(BatchNormalization())

    model.add(Dropout(dropout_rate))
    #model.add(BatchNormalization())
    model.add(Dense(1))

    # Compile model
    opt = adam(lr=learn_rate)
    model.summary()
    model.compile(loss='mse', optimizer= opt, metrics=['mean_squared_error','accuracy'])

    return model

# %%
## Run DNN for different batch size, learning and dropout rates

# %%
#%% create model
   
model = KerasRegressor(build_fn=create_model, verbose=2)
# grid search epochs, batch size and optimizer
batches = [16,32]
learn_rates = [0.0005,0.005,0.009,0.09,0.01]
dropout_rates = [0.23,0.25]

para = {}
for bt in batches:
    for lr in learn_rates:
        for dr in dropout_rates:
            print('batch_size: '+str(bt),'learn_rate: '+str(lr),'dropout_rate: '+str(dr))
            model=create_model(lr, dr)
            
            # CheckPoint
            filepath="weights.best.hdf5"
            checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
            callbacks_list = [checkpoint]
            # Fit the model
            hist = model.fit(X_train, Y_train, epochs=300, batch_size=bt, validation_data = (X_test, Y_test),callbacks=callbacks_list, verbose=0)
           
            # Load the opitimal weights
            model.load_weights("weights.best.hdf5")
            # Compile model (required to make predictions)
            model.compile(loss='mse', optimizer='adam', metrics=['mean_squared_error'])
            print("Created model and loaded weights from file") 
            
            # Prediction
            y_pred = model.predict(X_test)
            R2 = r2_score(Y_test, y_pred)
            
            y_pred_train = model.predict(X_train)
            R2_train = r2_score(Y_train, y_pred_train)
            
            # Save the model
            model_json = model.to_json()
            with open(str(R2)+ "_model.json", "w") as json_file:
                json_file.write(model_json)
            model.save_weights(str(R2)+ "_model.h5")
            para[R2] = (R2, R2_train, bt, lr, dr)

# Extract the best prameters
R2_max = max(para)
bt = para[R2_max][2]
lr = para[R2_max][3]
dr = para[R2_max][4]

#R2_max = 0.3234658252296695

json_file = open(str(R2_max)+'_model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights(str(R2_max)+"_model.h5")
print("Loaded best_model from disk")

# Prediction
y_pred = loaded_model.predict(X_test)

# The mean squared error
MSE = mean_squared_error(Y_test, y_pred)
RMSE = np.sqrt (MSE)
print("Tesing RMSE: %.3f" % RMSE)
testY_mean = np.mean(Y_test)
RRMSE = 100*RMSE/testY_mean
print("Tesing Relative RMSE: %.3f" % RRMSE)
R2 = r2_score(Y_test, y_pred)
print('Tesing R2: %.3f' % R2)

## Training accuracy metrics
y_pred_train = loaded_model.predict(X_train) 
MSE = mean_squared_error(Y_train, y_pred_train)
RMSE = np.sqrt (MSE)
print("RMSE of Training: %.3f" % RMSE)
trainY_mean = np.mean(Y_train)
RRMSE = 100*RMSE/trainY_mean
print("Relative RMSE of Trainging: %.3f" % RRMSE)
# Explained variance score: 1 is perfect prediction
print('Traing R2: %.3f' % r2_score(Y_train, y_pred_train))

y_pred_all = loaded_model.predict(X)

# Visulization
plt.scatter(Y_test,y_pred)
plt.show()
plt.scatter(Y_train,y_pred_train)
plt.show()
plt.scatter(Y,y_pred_all)
plt.show()
# Out:
# batch_size: 16 learn_rate: 0.0005 dropout_rate: 0.23
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 64)                12928
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               8320
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128)               512
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               131584
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 188,929
# Trainable params: 187,649
# Non-trainable params: 1,280
# _________________________________________________________________
#
# Epoch 00001: val_loss improved from inf to 783825.96404, saving model to weights.best.hdf5
#
# Epoch 00002: val_loss improved from 783825.96404 to 779829.13955, saving model to weights.best.hdf5
#
# Epoch 00003: val_loss improved from 779829.13955 to 777586.35360, saving model to weights.best.hdf5
#
# Epoch 00004: val_loss improved from 777586.35360 to 775506.71575, saving model to weights.best.hdf5
#
# Epoch 00005: val_loss improved from 775506.71575 to 775389.64812, saving model to weights.best.hdf5
#
# Epoch 00006: val_loss did not improve from 775389.64812
#
# Epoch 00007: val_loss did not improve from 775389.64812
#
# Epoch 00008: val_loss did not improve from 775389.64812
#
# Epoch 00009: val_loss did not improve from 775389.64812
#
# Epoch 00010: val_loss did not improve from 775389.64812
#
# Epoch 00011: val_loss did not improve from 775389.64812
#
# Epoch 00012: val_loss did not improve from 775389.64812
#
# Epoch 00013: val_loss did not improve from 775389.64812
#
# Epoch 00014: val_loss did not improve from 775389.64812
#
# Epoch 00015: val_loss improved from 775389.64812 to 756052.04880, saving model to weights.best.hdf5
#
# Epoch 00016: val_loss did not improve from 756052.04880
#
# Epoch 00017: val_loss did not improve from 756052.04880
#
# Epoch 00018: val_loss did not improve from 756052.04880
#
# Epoch 00019: val_loss did not improve from 756052.04880
#
# Epoch 00020: val_loss did not improve from 756052.04880
#
# Epoch 00021: val_loss did not improve from 756052.04880
#
# Epoch 00022: val_loss did not improve from 756052.04880
#
# Epoch 00023: val_loss did not improve from 756052.04880
#
# Epoch 00024: val_loss did not improve from 756052.04880
#
# Epoch 00025: val_loss did not improve from 756052.04880
#
# Epoch 00026: val_loss did not improve from 756052.04880
#
# Epoch 00027: val_loss did not improve from 756052.04880
#
# Epoch 00028: val_loss did not improve from 756052.04880
#
# Epoch 00029: val_loss did not improve from 756052.04880
#
# Epoch 00030: val_loss did not improve from 756052.04880
#
# Epoch 00031: val_loss improved from 756052.04880 to 715526.23202, saving model to weights.best.hdf5
#
# Epoch 00032: val_loss did not improve from 715526.23202
#
# Epoch 00033: val_loss did not improve from 715526.23202
#
# Epoch 00034: val_loss did not improve from 715526.23202
#
# Epoch 00035: val_loss did not improve from 715526.23202
#
# Epoch 00036: val_loss did not improve from 715526.23202
#
# Epoch 00037: val_loss did not improve from 715526.23202
#
# Epoch 00038: val_loss did not improve from 715526.23202
#
# Epoch 00039: val_loss did not improve from 715526.23202
#
# Epoch 00040: val_loss did not improve from 715526.23202
#
# Epoch 00041: val_loss improved from 715526.23202 to 688104.00086, saving model to weights.best.hdf5
#
# Epoch 00042: val_loss did not improve from 688104.00086
#
# Epoch 00043: val_loss improved from 688104.00086 to 659210.46918, saving model to weights.best.hdf5
#
# Epoch 00044: val_loss did not improve from 659210.46918
#
# Epoch 00045: val_loss did not improve from 659210.46918
#
# Epoch 00046: val_loss did not improve from 659210.46918
#
# Epoch 00047: val_loss did not improve from 659210.46918
#
# Epoch 00048: val_loss did not improve from 659210.46918
#
# Epoch 00049: val_loss did not improve from 659210.46918
#
# Epoch 00050: val_loss did not improve from 659210.46918
#
# Epoch 00051: val_loss improved from 659210.46918 to 656318.61901, saving model to weights.best.hdf5
#
# Epoch 00052: val_loss did not improve from 656318.61901
#
# Epoch 00053: val_loss did not improve from 656318.61901
#
# Epoch 00054: val_loss did not improve from 656318.61901
#
# Epoch 00055: val_loss did not improve from 656318.61901
#
# Epoch 00056: val_loss did not improve from 656318.61901
#
# Epoch 00057: val_loss did not improve from 656318.61901
#
# Epoch 00058: val_loss improved from 656318.61901 to 636135.06250, saving model to weights.best.hdf5
#
# Epoch 00059: val_loss did not improve from 636135.06250
#
# Epoch 00060: val_loss improved from 636135.06250 to 542585.97474, saving model to weights.best.hdf5
#
# Epoch 00061: val_loss did not improve from 542585.97474
#
# Epoch 00062: val_loss did not improve from 542585.97474
#
# Epoch 00063: val_loss did not improve from 542585.97474
#
# Epoch 00064: val_loss did not improve from 542585.97474
#
# Epoch 00065: val_loss did not improve from 542585.97474
#
# Epoch 00066: val_loss did not improve from 542585.97474
#
# Epoch 00067: val_loss did not improve from 542585.97474
#
# Epoch 00068: val_loss did not improve from 542585.97474
#
# Epoch 00069: val_loss did not improve from 542585.97474
#
# Epoch 00070: val_loss did not improve from 542585.97474
#
# Epoch 00071: val_loss did not improve from 542585.97474
#
# Epoch 00072: val_loss did not improve from 542585.97474
#
# Epoch 00073: val_loss did not improve from 542585.97474
#
# Epoch 00074: val_loss improved from 542585.97474 to 509259.10103, saving model to weights.best.hdf5
#
# Epoch 00075: val_loss did not improve from 509259.10103
#
# Epoch 00076: val_loss improved from 509259.10103 to 471381.87842, saving model to weights.best.hdf5
#
# Epoch 00077: val_loss did not improve from 471381.87842
#
# Epoch 00078: val_loss improved from 471381.87842 to 452027.14041, saving model to weights.best.hdf5
#
# Epoch 00079: val_loss did not improve from 452027.14041
#
# Epoch 00080: val_loss improved from 452027.14041 to 442864.61515, saving model to weights.best.hdf5
#
# Epoch 00081: val_loss did not improve from 442864.61515
#
# Epoch 00082: val_loss did not improve from 442864.61515
#
# Epoch 00083: val_loss did not improve from 442864.61515
#
# Epoch 00084: val_loss did not improve from 442864.61515
#
# Epoch 00085: val_loss improved from 442864.61515 to 416276.87243, saving model to weights.best.hdf5
#
# Epoch 00086: val_loss did not improve from 416276.87243
#
# Epoch 00087: val_loss did not improve from 416276.87243
#
# Epoch 00088: val_loss did not improve from 416276.87243
#
# Epoch 00089: val_loss did not improve from 416276.87243
#
# Epoch 00090: val_loss improved from 416276.87243 to 397370.91652, saving model to weights.best.hdf5
#
# Epoch 00091: val_loss improved from 397370.91652 to 284495.83155, saving model to weights.best.hdf5
#
# Epoch 00092: val_loss did not improve from 284495.83155
#
# Epoch 00093: val_loss did not improve from 284495.83155
#
# Epoch 00094: val_loss did not improve from 284495.83155
#
# Epoch 00095: val_loss did not improve from 284495.83155
#
# Epoch 00096: val_loss did not improve from 284495.83155
#
# Epoch 00097: val_loss did not improve from 284495.83155
#
# Epoch 00098: val_loss did not improve from 284495.83155
#
# Epoch 00099: val_loss did not improve from 284495.83155
#
# Epoch 00100: val_loss did not improve from 284495.83155
#
# Epoch 00101: val_loss did not improve from 284495.83155
#
# Epoch 00102: val_loss did not improve from 284495.83155
#
# Epoch 00103: val_loss did not improve from 284495.83155
#
# Epoch 00104: val_loss did not improve from 284495.83155
#
# Epoch 00105: val_loss did not improve from 284495.83155
# Epoch 00106: val_loss did not improve from 284495.83155
#
# Epoch 00107: val_loss did not improve from 284495.83155
#
# Epoch 00108: val_loss did not improve from 284495.83155
#
# Epoch 00109: val_loss did not improve from 284495.83155
#
# Epoch 00110: val_loss did not improve from 284495.83155
#
# Epoch 00111: val_loss did not improve from 284495.83155
#
# Epoch 00112: val_loss did not improve from 284495.83155
#
# Epoch 00113: val_loss did not improve from 284495.83155
#
# Epoch 00114: val_loss did not improve from 284495.83155
#
# Epoch 00115: val_loss did not improve from 284495.83155
#
# Epoch 00116: val_loss did not improve from 284495.83155
#
# Epoch 00117: val_loss did not improve from 284495.83155
#
# Epoch 00118: val_loss did not improve from 284495.83155
#
# Epoch 00119: val_loss improved from 284495.83155 to 263007.22624, saving model to weights.best.hdf5
#
# Epoch 00120: val_loss did not improve from 263007.22624
#
# Epoch 00121: val_loss improved from 263007.22624 to 261145.26284, saving model to weights.best.hdf5
#
# Epoch 00122: val_loss improved from 261145.26284 to 256408.82598, saving model to weights.best.hdf5
#
# Epoch 00123: val_loss improved from 256408.82598 to 221205.38442, saving model to weights.best.hdf5
#
# Epoch 00124: val_loss did not improve from 221205.38442
#
# Epoch 00125: val_loss improved from 221205.38442 to 196560.35873, saving model to weights.best.hdf5
#
# Epoch 00126: val_loss did not improve from 196560.35873
#
# Epoch 00127: val_loss did not improve from 196560.35873
#
# Epoch 00128: val_loss improved from 196560.35873 to 190530.69724, saving model to weights.best.hdf5
#
# Epoch 00129: val_loss did not improve from 190530.69724
#
# Epoch 00130: val_loss did not improve from 190530.69724
#
# Epoch 00131: val_loss did not improve from 190530.69724
#
# Epoch 00132: val_loss did not improve from 190530.69724
#
# Epoch 00133: val_loss did not improve from 190530.69724
#
# Epoch 00134: val_loss improved from 190530.69724 to 168890.94028, saving model to weights.best.hdf5
#
# Epoch 00135: val_loss did not improve from 168890.94028
#
# Epoch 00136: val_loss did not improve from 168890.94028
#
# Epoch 00137: val_loss did not improve from 168890.94028
#
# Epoch 00138: val_loss improved from 168890.94028 to 161671.45066, saving model to weights.best.hdf5
#
# Epoch 00139: val_loss improved from 161671.45066 to 132994.12853, saving model to weights.best.hdf5
#
# Epoch 00140: val_loss did not improve from 132994.12853
#
# Epoch 00141: val_loss did not improve from 132994.12853
#
# Epoch 00142: val_loss did not improve from 132994.12853
#
# Epoch 00143: val_loss did not improve from 132994.12853
#
# Epoch 00144: val_loss did not improve from 132994.12853
#
# Epoch 00145: val_loss did not improve from 132994.12853
#
# Epoch 00146: val_loss improved from 132994.12853 to 132663.31571, saving model to weights.best.hdf5
#
# Epoch 00147: val_loss did not improve from 132663.31571
#
# Epoch 00148: val_loss did not improve from 132663.31571
#
# Epoch 00149: val_loss improved from 132663.31571 to 130495.53756, saving model to weights.best.hdf5
#
# Epoch 00150: val_loss improved from 130495.53756 to 92289.41952, saving model to weights.best.hdf5
#
# Epoch 00151: val_loss did not improve from 92289.41952
#
# Epoch 00152: val_loss did not improve from 92289.41952
#
# Epoch 00153: val_loss did not improve from 92289.41952
#
# Epoch 00154: val_loss did not improve from 92289.41952
#
# Epoch 00155: val_loss did not improve from 92289.41952
#
# Epoch 00156: val_loss did not improve from 92289.41952
#
# Epoch 00157: val_loss improved from 92289.41952 to 85981.68937, saving model to weights.best.hdf5
#
# Epoch 00158: val_loss did not improve from 85981.68937
#
# Epoch 00159: val_loss did not improve from 85981.68937
#
# Epoch 00160: val_loss did not improve from 85981.68937
#
# Epoch 00161: val_loss did not improve from 85981.68937
#
# Epoch 00162: val_loss did not improve from 85981.68937
#
# Epoch 00163: val_loss did not improve from 85981.68937
#
# Epoch 00164: val_loss did not improve from 85981.68937
#
# Epoch 00165: val_loss improved from 85981.68937 to 85370.85124, saving model to weights.best.hdf5
#
# Epoch 00166: val_loss did not improve from 85370.85124
#
# Epoch 00167: val_loss improved from 85370.85124 to 68931.59578, saving model to weights.best.hdf5
#
# Epoch 00168: val_loss did not improve from 68931.59578
#
# Epoch 00169: val_loss did not improve from 68931.59578
#
# Epoch 00170: val_loss did not improve from 68931.59578
#
# Epoch 00171: val_loss did not improve from 68931.59578
#
# Epoch 00172: val_loss did not improve from 68931.59578
#
# Epoch 00173: val_loss did not improve from 68931.59578
#
# Epoch 00174: val_loss did not improve from 68931.59578
#
# Epoch 00175: val_loss did not improve from 68931.59578
#
# Epoch 00176: val_loss did not improve from 68931.59578
#
# Epoch 00177: val_loss did not improve from 68931.59578
#
# Epoch 00178: val_loss did not improve from 68931.59578
#
# Epoch 00179: val_loss improved from 68931.59578 to 44755.82449, saving model to weights.best.hdf5
#
# Epoch 00180: val_loss did not improve from 44755.82449
#
# Epoch 00181: val_loss did not improve from 44755.82449
#
# Epoch 00182: val_loss did not improve from 44755.82449
#
# Epoch 00183: val_loss did not improve from 44755.82449
#
# Epoch 00184: val_loss did not improve from 44755.82449
#
# Epoch 00185: val_loss improved from 44755.82449 to 40927.54258, saving model to weights.best.hdf5
#
# Epoch 00186: val_loss did not improve from 40927.54258
#
# Epoch 00187: val_loss improved from 40927.54258 to 40421.54808, saving model to weights.best.hdf5
#
# Epoch 00188: val_loss improved from 40421.54808 to 38478.83562, saving model to weights.best.hdf5
#
# Epoch 00189: val_loss improved from 38478.83562 to 30472.22512, saving model to weights.best.hdf5
#
# Epoch 00190: val_loss improved from 30472.22512 to 29979.09283, saving model to weights.best.hdf5
#
# Epoch 00191: val_loss did not improve from 29979.09283
#
# Epoch 00192: val_loss did not improve from 29979.09283
#
# Epoch 00193: val_loss did not improve from 29979.09283
#
# Epoch 00194: val_loss did not improve from 29979.09283
#
# Epoch 00195: val_loss did not improve from 29979.09283
#
# Epoch 00196: val_loss did not improve from 29979.09283
#
# Epoch 00197: val_loss did not improve from 29979.09283
#
# Epoch 00198: val_loss did not improve from 29979.09283
#
# Epoch 00199: val_loss did not improve from 29979.09283
#
# Epoch 00200: val_loss did not improve from 29979.09283
#
# Epoch 00201: val_loss did not improve from 29979.09283
#
# Epoch 00202: val_loss did not improve from 29979.09283
#
# Epoch 00203: val_loss did not improve from 29979.09283
#
# Epoch 00204: val_loss improved from 29979.09283 to 28000.44265, saving model to weights.best.hdf5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-17b6e20f898b> in <module>
#      19             callbacks_list = [checkpoint]
#      20             # Fit the model
# ---> 21             hist = model.fit(X_train, Y_train, epochs=300, batch_size=bt, validation_data = (X_test, Y_test),callbacks=callbacks_list, verbose=0)
#      22
#      23             # Load the opitimal weights
#
# ~\AppData\Local\conda\conda\envs\Tensorflow\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# ~\AppData\Local\conda\conda\envs\Tensorflow\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# ~\AppData\Local\conda\conda\envs\Tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~\AppData\Local\conda\conda\envs\Tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~\AppData\Local\conda\conda\envs\Tensorflow\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
